# %%
# !pip uninstall bson
# !pip uninstall pymongo
# !pip install pymongo
# Out:
# WARNING: Skipping bson as it is not installed.
# Found existing installation: pymongo 4.11.2
# Uninstalling pymongo-4.11.2:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/bson/*
#     /usr/local/lib/python3.11/dist-packages/gridfs/*
#     /usr/local/lib/python3.11/dist-packages/pymongo-4.11.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/pymongo/*
# Proceed (Y/n)? Y
#   Successfully uninstalled pymongo-4.11.2
# ...
#   Using cached pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ...
# Using cached pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# ...

# %%
from pymongo import MongoClient

brand_names = ['oneplus', 'samsung', 'motorola', 'realme', 'apple', 'xiaomi',
               'nothing', 'oppo', 'vivo', 'poco', 'iqoo', 'jio', 'gionee',
               'tecno', 'tesla', 'google', 'infinix', 'cola', 'letv', 'ikall',
               'leeco', 'duoqin', 'nokia', 'lava', 'honor', 'nubia', 'redmi',
               'asus', 'itel', 'royole', 'sony', 'oukitel', 'vertu', 'blu',
               'lyf', 'huawei', 'zte', 'lenovo', 'lg', 'micromax',
               'leitz', 'cat', 'doogee', 'tcl', 'sharp', 'blackview']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-6c7e9203c9ec> in <cell line: 0>()
# ----> 1 from pymongo import MongoClient
#       2
#       3 brand_names = ['oneplus', 'samsung', 'motorola', 'realme', 'apple', 'xiaomi',
#       4                'nothing', 'oppo', 'vivo', 'poco', 'iqoo', 'jio', 'gionee',
#       5                'tecno', 'tesla', 'google', 'infinix', 'cola', 'letv', 'ikall',
#
# /usr/local/lib/python3.11/dist-packages/pymongo/__init__.py in <module>
#      89 from pymongo import _csot
#      90 from pymongo._version import __version__, get_version_string, version_tuple
# ---> 91 from pymongo.asynchronous.mongo_client import AsyncMongoClient
#      92 from pymongo.common import MAX_SUPPORTED_WIRE_VERSION, MIN_SUPPORTED_WIRE_VERSION, has_c
#      93 from pymongo.cursor import CursorType
#
# ...

# %%
client = MongoClient("mongodb+srv://bijan2059:SFgwjeXqkpLTA5FL@cluster0.escecda.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0&dbname=phoneShop")

# %%
db = client['phoneShop']  # Replace with your database name
collection = db['brands']  # Replace with your collection name
brand_dict = {}
# Function to insert brands

def insert_brands():
    try:
        for brand_name in brand_names:
            # Create a dictionary representing the brand document
            brand_doc = {
                "name": brand_name,
            }

            # Insert the brand document into the collection
            result = collection.insert_one(brand_doc)
            print(f"Brand {brand_name} inserted with ID: {result.inserted_id}")

            # Add brand name and ID to the dictionary
            brand_dict[brand_name] = result.inserted_id
    except Exception as e:
        print(f"Error inserting brands: {e}")

# %%
# Call the function to insert brands
# insert_brands()
# print(brand_dict)

# %%
import numpy as np
import pandas as pd
import ast
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('/content/drive/MyDrive/Phone Recommendation and Similarity/datasets/cleaned.csv')

# %%
df.columns

# %%
# df['brand'] = df['brand_name'].map(brand_dict)

# %%
# df[['brand','brand_name']]

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Phone Recommendation and Similarity/datasets/smartphone_cleaned_v5.csv')

# %%
# Handle missing values
df2['primary_camera_front'] = df2['primary_camera_front'].fillna(df2['primary_camera_front'].median())

# %%
df['primary_camera_front'] = df2['primary_camera_front']
df['primary_camera_rear'] = df2['primary_camera_rear']

# %%
# !pip install bson

# %%
from bson import ObjectId
products_collection = db['products']
# Function to insert data into MongoDB
def insert_products(df):
    try:
        for index, row in df.iterrows():
            # Create a document representing the product
            product_doc = {
                "name": row['model'],
                "price": row['price'],
                "brand": ObjectId(row['brand']),  # Convert brand to ObjectId
                "specifications": {
                    "ram_capacity": row['ram_capacity'],
                    "internal_memory": row['internal_memory'],
                    "screen_size": row['screen_size'],
                    "battery_capacity": row['battery_capacity'],
                    "processor": row['processor_brand'],
                    "primary_camera_rear": row['primary_camera_rear'],
                    "primary_camera_front": row['primary_camera_front']
                },
                "images": [],
                "averageRating": 0,
                "totalRatings": 0
            }

            # Insert the product document into the collection
            result = products_collection.insert_one(product_doc)
            print(f"Product {row['model']} inserted with ID: {result.inserted_id}")
    except Exception as e:
        print(f"Error inserting products: {e}")

# Call the function to start inserting data
# insert_products(df)

# %%
import requests
from pymongo import MongoClient
from bson import ObjectId

# Function to get image URLs for a model (same as before)
def get_image_urls(model_name, num_images=3):
    api_key = "AIzaSyDf0kHJe1HGJEtMMgujInAsyZhWeMVZnpI"
    cse_id = "d19b77460e3f64d31"
    url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={cse_id}&q={model_name}&searchType=image"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
        data = response.json()

        image_urls = []
        if 'items' in data:
            for item in data['items'][:num_images]:  # Limit to num_images
                image_urls.append(item['link'])
        return image_urls
    except requests.exceptions.RequestException as e:
        print(f"Error during API request: {e}")
        return []
    except (KeyError, TypeError) as e:
        print(f"Error parsing JSON response: {e}")
        return []

# Function to update product images
def update_product_images():
    try:
        # Find all products
        products = products_collection.find()

        for product in products:
            model_name = product['name']
            print(f"Checking images for {model_name}...")

            # Check if the product already has images
            if not product.get('images') or len(product.get('images', [])) == 0:
                print(f"Updating images for {model_name}...")

                # Get image URLs for the model
                image_urls = get_image_urls(model_name)

                # Update the product document with the image URLs
                if image_urls:
                    products_collection.update_one(
                        {"_id": product["_id"]},
                        {"$addToSet": {"images": {"$each": image_urls}}}
                    )
                    print(f"Images updated for {model_name}")
                else:
                    print(f"No images found for {model_name}")
            else:
                print(f"Skipping {model_name} as it already has images.")
    except Exception as e:
        print(f"Error updating product images: {e}")

# Call the function to update product images
update_product_images()

# %%
import requests

def get_image_url(model_name):
    api_key = "AIzaSyDf0kHJe1HGJEtMMgujInAsyZhWeMVZnpI"
    cse_id = "d19b77460e3f64d31"
    url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={cse_id}&q={model_name}&searchType=image"

    response = requests.get(url)
    data = response.json()

    if 'items' in data:
        return data['items'][0]['link']
    else:
        return None

print(get_image_url('Motorola Moto S30 Pro'))

# %%
def update_stock():
    try:
        # Update stock for all products
        products_collection.update_many({}, {"$set": {"stock": 25}})
        print("Stock updated for all products.")
    except Exception as e:
        print(f"Error updating stock: {e}")

# Call the function to update stock
update_stock()
